# %%
import os
# %matplotlib inline

# %%
minNodes = 3
maxNodes = 6

edgeVALUEMAP = [1,15,2,25,5]
indexCount = 0
for i in range(minNodes, maxNodes):
    for k in range(len(edgeVALUEMAP)):
        
        foldername = str(edgeVALUEMAP[k])
        runCommand = "python predict.py -i ../data/validation/node" + str(i) + "_" + str(foldername)
        # !$runCommand
        print(runCommand)
# Out:
# ['../data/validation/node3_1/566.png', '../data/validation/node3_1/572.png', '../data/validation/node3_1/599.png', '../data/validation/node3_1/598.png', '../data/validation/node3_1/573.png', '../data/validation/node3_1/567.png', '../data/validation/node3_1/559.png', '../data/validation/node3_1/571.png', '../data/validation/node3_1/565.png', '../data/validation/node3_1/564.png', '../data/validation/node3_1/570.png', '../data/validation/node3_1/558.png', '../data/validation/node3_1/574.png', '../data/validation/node3_1/560.png', '../data/validation/node3_1/548.png', '../data/validation/node3_1/549.png', '../data/validation/node3_1/561.png', '../data/validation/node3_1/575.png', '../data/validation/node3_1/563.png', '../data/validation/node3_1/577.png', '../data/validation/node3_1/588.png', '../data/validation/node3_1/589.png', '../data/validation/node3_1/576.png', '../data/validation/node3_1/562.png', '../data/validation/node3_1/539.png', '../data/validation/node3_1/505.png', '../data/validation/node3_1/511.png', '../data/validation/node3_1/510.png', '../data/validation/node3_1/504.png', '../data/validation/node3_1/538.png', '../data/validation/node3_1/512.png', '../data/validation/node3_1/506.png', '../data/validation/node3_1/507.png', '../data/validation/node3_1/513.png', '../data/validation/node3_1/517.png', '../data/validation/node3_1/503.png', '../data/validation/node3_1/502.png', '../data/validation/node3_1/516.png', '../data/validation/node3_1/500.png', '../data/validation/node3_1/514.png', '../data/validation/node3_1/528.png', '../data/validation/node3_1/529.png', '../data/validation/node3_1/515.png', '../data/validation/node3_1/501.png', '../data/validation/node3_1/518.png', '../data/validation/node3_1/524.png', '../data/validation/node3_1/530.png', '../data/validation/node3_1/531.png', '../data/validation/node3_1/525.png', '../data/validation/node3_1/519.png', '../data/validation/node3_1/533.png', '../data/validation/node3_1/527.png', '../data/validation/node3_1/526.png', '../data/validation/node3_1/532.png', '../data/validation/node3_1/536.png', '../data/validation/node3_1/522.png', '../data/validation/node3_1/523.png', '../data/validation/node3_1/537.png', '../data/validation/node3_1/521.png', '../data/validation/node3_1/535.png', '../data/validation/node3_1/509.png', '../data/validation/node3_1/508.png', '../data/validation/node3_1/534.png', '../data/validation/node3_1/520.png', '../data/validation/node3_1/547.png', '../data/validation/node3_1/553.png', '../data/validation/node3_1/584.png', '../data/validation/node3_1/590.png', '../data/validation/node3_1/591.png', '../data/validation/node3_1/585.png', '../data/validation/node3_1/552.png', '../data/validation/node3_1/546.png', '../data/validation/node3_1/578.png', '../data/validation/node3_1/550.png', '../data/validation/node3_1/544.png', '../data/validation/node3_1/593.png', '../data/validation/node3_1/587.png', '../data/validation/node3_1/586.png', '../data/validation/node3_1/592.png', '../data/validation/node3_1/545.png', '../data/validation/node3_1/551.png', '../data/validation/node3_1/579.png', '../data/validation/node3_1/555.png', '../data/validation/node3_1/541.png', '../data/validation/node3_1/569.png', '../data/validation/node3_1/596.png', '../data/validation/node3_1/582.png', '../data/validation/node3_1/583.png', '../data/validation/node3_1/597.png', '../data/validation/node3_1/568.png', '../data/validation/node3_1/540.png', '../data/validation/node3_1/554.png', '../data/validation/node3_1/542.png', '../data/validation/node3_1/556.png', '../data/validation/node3_1/581.png', '../data/validation/node3_1/595.png', '../data/validation/node3_1/594.png', '../data/validation/node3_1/580.png', '../data/validation/node3_1/557.png', '../data/validation/node3_1/543.png']
#   0%|                                                   | 0/100 [00:00<?, ?it/s]../data/validation/node3_1/566.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   g
# ../ocr/demo_image/1.png   c
# ../ocr/demo_image/2.png   a
# 0
# []
# (51, 71, 126, 146)
# (84, 104, 127, 147)
# 1
# [2]
# 2
# []
# c,a
# 1 1 1 2 2
#   1%|▍                                          | 1/100 [00:22<36:42, 22.25s/it]../data/validation/node3_1/572.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   e
# ../ocr/demo_image/1.png   b
# ../ocr/demo_image/2.png   f
# 0
# []
# (51, 71, 126, 146)
# (84, 104, 127, 147)
# 1
# [2]
# 2
# []
# b,f
# 1 1 1 2 2
#   2%|▊                                          | 2/100 [00:47<37:56, 23.23s/it]../data/validation/node3_1/599.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   d
# ../ocr/demo_image/1.png   g
# ../ocr/demo_image/2.png   e
# 0
# []
# (51, 71, 126, 146)
# (84, 104, 127, 147)
# 1
# [2]
# 2
# []
# g,e
# 1 1 1 2 2
#   3%|█▎                                         | 3/100 [01:15<39:36, 24.51s/it]../data/validation/node3_1/598.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   c
# ../ocr/demo_image/1.png   a
# ../ocr/demo_image/2.png   e
# 0
# []
# (51, 71, 126, 146)
# (84, 104, 127, 147)
# 1
# [2]
# 2
# []
# a,e
# 1 1 1 2 2
#   4%|█▋                                         | 4/100 [01:41<39:59, 24.99s/it]../data/validation/node3_1/573.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   g
# ../ocr/demo_image/1.png   h
# ../ocr/demo_image/2.png   b
# (51, 71, 31, 51)
# (84, 104, 30, 50)
# 0
# [2]
# 1
# []
# 2
# []
# g,b
# 1 1 1 2 2
#   5%|██▏                                        | 5/100 [02:08<40:22, 25.50s/it]../data/validation/node3_1/567.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   e
# ../ocr/demo_image/1.png   c
# ../ocr/demo_image/2.png   f
# (51, 71, 31, 51)
# (84, 104, 30, 50)
# 0
# [2]
# 1
# []
# 2
# []
# e,f
# 1 1 1 2 2
#   6%|██▌                                        | 6/100 [02:30<38:41, 24.70s/it]../data/validation/node3_1/559.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   e
# ../ocr/demo_image/1.png   b
# ../ocr/demo_image/2.png   f
# (51, 71, 31, 51)
# (84, 104, 30, 50)
# 0
# [2]
# 1
# []
# 2
# []
# e,f
# 1 1 1 2 2
#   7%|███                                        | 7/100 [02:54<37:41, 24.32s/it]../data/validation/node3_1/571.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   f
# ../ocr/demo_image/1.png   b
# ../ocr/demo_image/2.png   a
# (51, 71, 31, 51)
# (84, 104, 30, 50)
# 0
# [2]
# 1
# []
# 2
# []
# f,a
# 1 1 1 2 2
#   8%|███▍                                       | 8/100 [03:18<37:18, 24.33s/it]../data/validation/node3_1/565.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   f
# ../ocr/demo_image/1.png   g
# ../ocr/demo_image/2.png   h
# 0
# []
# (51, 71, 126, 146)
# (84, 104, 127, 147)
# 1
# [2]
# 2
# []
# g,h
# 1 1 1 2 2
#   9%|███▊                                       | 9/100 [03:42<36:43, 24.21s/it]../data/validation/node3_1/564.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   f
# ../ocr/demo_image/1.png   c
# ../ocr/demo_image/2.png   e
# 0
# []
# (51, 71, 126, 146)
# (84, 104, 127, 147)
# 1
# [2]
# 2
# []
# c,e
# 1 1 1 2 2
#  10%|████▏                                     | 10/100 [04:06<36:13, 24.15s/it]../data/validation/node3_1/570.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   a
# ../ocr/demo_image/1.png   e
# ../ocr/demo_image/2.png   b
# (51, 71, 31, 51)
# (84, 104, 30, 50)
# 0
# [2]
# 1
# []
# 2
# []
# a,b
# 1 1 1 2 2
#  11%|████▌                                     | 11/100 [04:29<35:25, 23.88s/it]../data/validation/node3_1/558.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   c
# ../ocr/demo_image/1.png   h
# ../ocr/demo_image/2.png   a
# (51, 71, 31, 51)
# (84, 104, 30, 50)
# 0
# [2]
# 1
# []
# 2
# []
# c,a
# 1 1 1 2 2
#  12%|█████                                     | 12/100 [04:53<34:56, 23.82s/it]../data/validation/node3_1/574.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   f
# ../ocr/demo_image/1.png   g
# ../ocr/demo_image/2.png   h
# 0
# []
# (51, 71, 126, 146)
# (84, 104, 127, 147)
# 1
# [2]
# 2
# []
# g,h
# 1 1 1 2 2
#  13%|█████▍                                    | 13/100 [05:16<34:11, 23.58s/it]../data/validation/node3_1/560.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   g
# ../ocr/demo_image/1.png   f
# ../ocr/demo_image/2.png   e
# 0
# []
# (51, 71, 126, 146)
# (84, 104, 127, 147)
# 1
# [2]
# 2
# []
# f,e
# 1 1 1 2 2
#  14%|█████▉                                    | 14/100 [05:40<33:52, 23.63s/it]../data/validation/node3_1/548.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   c
# ../ocr/demo_image/1.png   g
# ../ocr/demo_image/2.png   d
# (51, 71, 31, 51)
# (84, 104, 30, 50)
# 0
# [2]
# 1
# []
# 2
# []
# c,d
# 1 1 1 2 2
#  15%|██████▎                                   | 15/100 [06:03<33:26, 23.61s/it]../data/validation/node3_1/549.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   f
# ../ocr/demo_image/1.png   d
# ../ocr/demo_image/2.png   h
# 0
# []
# (51, 71, 126, 146)
# (84, 104, 127, 147)
# 1
# [2]
# 2
# []
# d,h
# 1 1 1 2 2
#  16%|██████▋                                   | 16/100 [06:27<32:57, 23.55s/it]../data/validation/node3_1/561.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   a
# ../ocr/demo_image/1.png   e
# ../ocr/demo_image/2.png   h
# (51, 71, 31, 51)
# (84, 104, 30, 50)
# 0
# [2]
# 1
# []
# 2
# []
# a,h
# 1 1 1 2 2
#  17%|███████▏                                  | 17/100 [06:53<33:33, 24.26s/it]../data/validation/node3_1/575.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   e
# ../ocr/demo_image/1.png   g
# ../ocr/demo_image/2.png   a
# 0
# []
# (51, 71, 126, 146)
# (84, 104, 127, 147)
# 1
# [2]
# 2
# []
# g,a
# 1 1 1 2 2
#  18%|███████▌                                  | 18/100 [07:19<33:50, 24.76s/it]../data/validation/node3_1/563.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   g
# ../ocr/demo_image/1.png   d
# ../ocr/demo_image/2.png   f
# (51, 71, 31, 51)
# (84, 104, 30, 50)
# 0
# [2]
# 1
# []
# 2
# []
# g,f
# 1 1 1 2 2
#  19%|███████▉                                  | 19/100 [07:44<33:29, 24.81s/it]../data/validation/node3_1/577.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   d
# ../ocr/demo_image/1.png   a
# ../ocr/demo_image/2.png   g
# 0
# []
# (51, 71, 126, 146)
# (84, 104, 127, 147)
# 1
# [2]
# 2
# []
# a,g
# 1 1 1 2 2
#  20%|████████▍                                 | 20/100 [08:06<32:19, 24.25s/it]../data/validation/node3_1/588.png
# False
# Here
# /Users/kuncao/Documents/ObjectDetection/unet/utils/data_bayes.py:273: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(1, classes + 1)
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   g
# ../ocr/demo_image/1.png   b
# ../ocr/demo_image/2.png   e
# (51, 71, 31, 51)
# (84, 104, 30, 50)
# 0
# [2]
# 1
# []
# 2
# []
# g,e
# 1 1 1 2 2
#  21%|████████▊                                 | 21/100 [08:31<31:54, 24.24s/it]../data/validation/node3_1/589.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   g
# ../ocr/demo_image/1.png   f
# ../ocr/demo_image/2.png   d

# %%
# !python predict.py -i ../data/validation/test -p True
# !python predict.py -i ../data/validation/test
# Out:
# ['../data/validation/test/0.png']
#   0%|                                                     | 0/1 [00:00<?, ?it/s]../data/validation/test/0.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   e
# ../ocr/demo_image/1.png   h
# ../ocr/demo_image/2.png   h
# ../ocr/demo_image/3.png   c
# ../ocr/demo_image/4.png   e
# ../ocr/demo_image/5.png   a
# ../ocr/demo_image/6.png   b
# (52, 72, 31, 51)
# (84, 104, 30, 50)
# 0
# [1]
# 1
# []
# e,h
# 1 1 1 2 2
# 100%|█████████████████████████████████████████████| 1/1 [00:22<00:00, 22.22s/it]
