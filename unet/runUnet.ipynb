# %%
import os
# %matplotlib inline

# %%
minNodes = 1
maxNodes = 7

edgeList = [.1, .25, .5]
edgeVALUEMAP = [1,25,5]
indexCount = 0
for i in range(maxNodes, minNodes, -1):
    for k in range(len(edgeList)):
        
        foldername = str(edgeVALUEMAP[k])
        runCommand = "python predict.py -i ../data/validation/node" + str(i) + "_" + str(foldername)
        # !$runCommand
        print(runCommand)

# %%
# !python predict.py -i ../data/validation/test -p True
# !python predict.py -i ../data/validation/test
# Out:
# ['../data/validation/test/53.png']
#   0%|                                                     | 0/1 [00:00<?, ?it/s]../data/validation/test/53.png
# False
# Here
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# loading pretrained model from ../ocr/TPS-ResNet-BiLSTM-Attn.pth
# ../ocr/demo_image/0.png   h
# ../ocr/demo_image/1.png   a
# ../ocr/demo_image/2.png   a
# ../ocr/demo_image/3.png   b
# ../ocr/demo_image/4.png   er
# ../ocr/demo_image/5.png   a
# ../ocr/demo_image/6.png   a
# (57, 71, 180, 194)
# (56, 70, 179, 193)
# (57, 71, 178, 192)
# (56, 70, 195, 209)
# (85, 99, 202, 216)
# (56, 70, 194, 208)
# (475, 489, 332, 346)
# (38, 52, 231, 245)
# (39, 53, 133, 147)
# (38, 52, 134, 148)
# 0
# [1, 6]
# (164, 178, 165, 179)
# (164, 178, 166, 180)
# (165, 179, 168, 182)
# (164, 178, 167, 181)
# (468, 482, 311, 325)
# (142, 156, 215, 229)
# (172, 186, 218, 232)
# (143, 157, 214, 228)
# (52, 66, 156, 170)
# (71, 85, 139, 153)
# (160, 174, 106, 120)
# ...
